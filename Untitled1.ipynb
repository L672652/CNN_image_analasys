# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import os
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix
data = tf.keras.utils.image_dataset_from_directory('EuroSAT_RGB/EuroSAT_RGB', image_size=(64,64))
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()
scaled = batch[0]/255
scaled.max()

data = data.map(lambda x,y: (x/255, tf.one_hot(y, depth=10)))
scaled_iterator = data.as_numpy_iterator()
batch = scaled_iterator.next()

batch[0].min()

len(data)

train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

X_val_list = []
Y_val_list = []

model = Sequential()
model.add(Conv2D(16,(3,3),1,activation='relu',input_shape=(64,64,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())


model.add(Dense(256,activation='relu'))
model.add(Dense(10, activation = "softmax"))


model.compile('adam' , loss = "categorical_crossentropy", metrics=["accuracy"])
model.summary()

logdir='logs'
print(train.element_spec)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train,epochs=10,validation_data=val, callbacks=[tensorboard_callback])

model.save('SateliteModel')

for features, labels in val:
    X_val_list.append(features)
    Y_val_list.append(labels)
    
X_val = tf.concat(X_val_list, axis=0)
Y_val = tf.concat(Y_val_list, axis=0)

plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test, verbose=2)

import seaborn as sns
# Predict the values from the validation dataset
Y_pred = model.predict(X_val)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(Y_val,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
# plot the confusion matrix
f,ax = plt.subplots(figsize=(8, 8))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.01,cmap="Greens",linecolor="gray", fmt= '.1f',ax=ax)
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Found 27000 files belonging to 10 classes.
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 62, 62, 16)        448
#
#  max_pooling2d_6 (MaxPooling  (None, 31, 31, 16)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 29, 29, 32)        4640
#
#  max_pooling2d_7 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 12, 12, 16)        4624
#
#  max_pooling2d_8 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 576)               0
#
#  dense_4 (Dense)             (None, 256)               147712
#
#  dense_5 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 159,994
# Trainable params: 159,994
# Non-trainable params: 0
# _________________________________________________________________
# (TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))
# Epoch 1/10
# 590/590 [==============================] - 12s 20ms/step - loss: 1.2996 - accuracy: 0.5063 - val_loss: 1.2347 - val_accuracy: 0.5227
# Epoch 2/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.9075 - accuracy: 0.6699 - val_loss: 0.8544 - val_accuracy: 0.6856
# Epoch 3/10
# 590/590 [==============================] - 7s 11ms/step - loss: 0.7981 - accuracy: 0.7115 - val_loss: 0.7822 - val_accuracy: 0.7180
# Epoch 4/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.7451 - accuracy: 0.7325 - val_loss: 0.8315 - val_accuracy: 0.6953
# Epoch 5/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.6607 - accuracy: 0.7593 - val_loss: 0.6574 - val_accuracy: 0.7640
# Epoch 6/10
# 590/590 [==============================] - 7s 13ms/step - loss: 0.6089 - accuracy: 0.7788 - val_loss: 0.5926 - val_accuracy: 0.7853
# Epoch 7/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.5603 - accuracy: 0.7970 - val_loss: 0.5548 - val_accuracy: 0.7982
# Epoch 8/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.5169 - accuracy: 0.8137 - val_loss: 0.6456 - val_accuracy: 0.7660
# Epoch 9/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.5070 - accuracy: 0.8197 - val_loss: 0.5269 - val_accuracy: 0.8110
# Epoch 10/10
# 590/590 [==============================] - 7s 12ms/step - loss: 0.4588 - accuracy: 0.8357 - val_loss: 0.5594 - val_accuracy: 0.7985
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: SateliteModel\assets
# INFO:tensorflow:Assets written to: SateliteModel\assets
# 84/84 - 3s - loss: 0.5850 - accuracy: 0.7935 - 3s/epoch - 40ms/step
# 168/168 [==============================] - 1s 3ms/step
