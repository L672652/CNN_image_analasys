# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import os
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from sklearn.metrics import confusion_matrix
from tensorflow.keras.metrics import Precision, BinaryAccuracy
data = tf.keras.utils.image_dataset_from_directory('EuroSAT_RGB/EuroSAT_RGB', image_size=(64,64))
data_iterator = data.as_numpy_iterator()
batch = data_iterator.next()
scaled = batch[0]/255
scaled.max()

data = data.map(lambda x,y: (x/255, tf.one_hot(y, depth=10)))
scaled_iterator = data.as_numpy_iterator()
batch = scaled_iterator.next()

train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

X_val_list = []
Y_val_list = []

model = Sequential()
model.add(Conv2D(16,(3,3),1,activation='relu',input_shape=(64,64,3)))
model.add(MaxPooling2D())

model.add(Conv2D(32,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Conv2D(16,(3,3),1,activation='relu'))
model.add(MaxPooling2D())

model.add(Flatten())


model.add(Dense(512,activation='relu'))
model.add(Dense(10, activation = "softmax"))


model.compile('adam' , loss = "categorical_crossentropy", metrics=["accuracy"])
model.summary()

logdir='logs'
print(train.element_spec)
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)
hist = model.fit(train,epochs=20,validation_data=val, callbacks=[tensorboard_callback])

model.save('SateliteModel')

for features, labels in val:
    X_val_list.append(features)
    Y_val_list.append(labels)
    
X_val = tf.concat(X_val_list, axis=0)
Y_val = tf.concat(Y_val_list, axis=0)

plt.plot(hist.history['accuracy'], label='accuracy')
plt.plot(hist.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoker')
plt.ylabel('Treffsikkehet')
plt.legend(loc='lower right')
plt.show()

model.evaluate(test, verbose=2)

Y_pred = model.predict(X_val)
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
Y_true = np.argmax(Y_val,axis = 1) 
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes) 
f,ax = plt.subplots(figsize=(12, 12))
sns.heatmap(confusion_mtx, annot=True, linewidths=0.02,cmap="Blues",linecolor="yellow", fmt= '.0f',ax=ax)
plt.xlabel("Predikert Terreng")
plt.ylabel("Sanne Terreng")
plt.title("Matrise som viser treffsikkerhet (confusion matrix)")
plt.show()
# Out:
# Found 26984 files belonging to 10 classes.
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 62, 62, 16)        448
#
#  max_pooling2d_36 (MaxPoolin  (None, 31, 31, 16)       0
#  g2D)
#
#  conv2d_37 (Conv2D)          (None, 29, 29, 32)        4640
#
#  max_pooling2d_37 (MaxPoolin  (None, 14, 14, 32)       0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 12, 12, 16)        4624
#
#  max_pooling2d_38 (MaxPoolin  (None, 6, 6, 16)         0
#  g2D)
#
#  flatten_12 (Flatten)        (None, 576)               0
#
#  dense_24 (Dense)            (None, 512)               295424
#
#  dense_25 (Dense)            (None, 10)                5130
#
# =================================================================
# Total params: 310,266
# Trainable params: 310,266
# Non-trainable params: 0
# _________________________________________________________________
# (TensorSpec(shape=(None, 64, 64, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 10), dtype=tf.float32, name=None))
# Epoch 1/20
# 590/590 [==============================] - 7s 12ms/step - loss: 1.2904 - accuracy: 0.5049 - val_loss: 1.1079 - val_accuracy: 0.5776
# Epoch 2/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.8526 - accuracy: 0.6880 - val_loss: 0.8714 - val_accuracy: 0.6773
# Epoch 3/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.7181 - accuracy: 0.7386 - val_loss: 0.6361 - val_accuracy: 0.7799
# Epoch 4/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.6624 - accuracy: 0.7581 - val_loss: 0.6345 - val_accuracy: 0.7710
# Epoch 5/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.6152 - accuracy: 0.7737 - val_loss: 0.6137 - val_accuracy: 0.7816
# Epoch 6/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.5645 - accuracy: 0.7946 - val_loss: 0.5448 - val_accuracy: 0.8129
# Epoch 7/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.5268 - accuracy: 0.8073 - val_loss: 0.5238 - val_accuracy: 0.8173
# Epoch 8/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.4948 - accuracy: 0.8192 - val_loss: 0.5169 - val_accuracy: 0.8183
# Epoch 9/20
# 590/590 [==============================] - 7s 11ms/step - loss: 0.4591 - accuracy: 0.8327 - val_loss: 0.5528 - val_accuracy: 0.8036
# Epoch 10/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.4335 - accuracy: 0.8419 - val_loss: 0.5255 - val_accuracy: 0.8218
# Epoch 11/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.3991 - accuracy: 0.8584 - val_loss: 0.5059 - val_accuracy: 0.8209
# Epoch 12/20
# 590/590 [==============================] - 7s 11ms/step - loss: 0.3913 - accuracy: 0.8582 - val_loss: 0.5314 - val_accuracy: 0.8194
# Epoch 13/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.3478 - accuracy: 0.8719 - val_loss: 0.5012 - val_accuracy: 0.8259
# Epoch 14/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.3207 - accuracy: 0.8849 - val_loss: 0.4895 - val_accuracy: 0.8358
# Epoch 15/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.2938 - accuracy: 0.8954 - val_loss: 0.4958 - val_accuracy: 0.8428
# Epoch 16/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.2632 - accuracy: 0.9080 - val_loss: 0.5331 - val_accuracy: 0.8268
# Epoch 17/20
# 590/590 [==============================] - 7s 13ms/step - loss: 0.2570 - accuracy: 0.9095 - val_loss: 0.5379 - val_accuracy: 0.8365
# Epoch 18/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.2184 - accuracy: 0.9231 - val_loss: 0.8388 - val_accuracy: 0.7738
# Epoch 19/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.2199 - accuracy: 0.9236 - val_loss: 0.5549 - val_accuracy: 0.8348
# Epoch 20/20
# 590/590 [==============================] - 7s 12ms/step - loss: 0.1876 - accuracy: 0.9338 - val_loss: 0.6631 - val_accuracy: 0.8257
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: SateliteModel\assets
# INFO:tensorflow:Assets written to: SateliteModel\assets
# 84/84 - 4s - loss: 0.6541 - accuracy: 0.8196 - 4s/epoch - 43ms/step
# 168/168 [==============================] - 0s 2ms/step
